# %% [markdown]
# <a href="https://colab.research.google.com/github/fangya18/Data-science/blob/master/Lymphoma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# authenticate Bigquery and Google Drive
from google.colab import auth
auth.authenticate_user()

# mount your drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import datetime as dt
import re
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
cd drive/MyDrive/HU/lymphoma/
# Out:
# /content/drive/MyDrive/HU/lymphoma

# %%
df = pd.read_csv('LP1.csv')
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT03415399  Clinical Study of ET190L1 ARTEMIS™ in Relapsed...
# 1     2  NCT01334502  Everolimus, Rituximab, and Combination Chemoth...
# 2     3  NCT03039114  Study Evaluating Safety and Efficacy of INCB05...
# 3     4  NCT04103905  A Study of MIL62 in Treatment of CD20 Positive...
# 4     5  NCT02741388  A Phase Ib Study of Oral Selinexor in Adult Pa...
#
#    Acronym     Status         Study Results  \
# 0      NaN  Completed  No Results Available
# 1      NaN  Completed  No Results Available
# 2      NaN  Completed  No Results Available
# 3      NaN  Completed  No Results Available
# 4  SELINDA  Completed  No Results Available
#
#                                   Conditions  \
# 0                           Lymphoma, B-Cell
# 1                                   Lymphoma
# 2                                   Lymphoma
# 3  CD20-positive B Cell Non-Hodgkin Lymphoma
# ...

# %% [markdown]
# ### Choose varaibles
# - Age
# - Gender
# - Enrollment
# - Sponsor

# %%
df.columns = df.columns.str.lower()

# %%
df[['start date','completion date']] = df[['start date','completion date']].apply(pd.to_datetime)
df['duration'] = (df['completion date'] - df['start date']).dt.days

# %%
df.head()
# Out:
#    rank   nct number                                              title  \
# 0     1  NCT03415399  Clinical Study of ET190L1 ARTEMIS™ in Relapsed...
# 1     2  NCT01334502  Everolimus, Rituximab, and Combination Chemoth...
# 2     3  NCT03039114  Study Evaluating Safety and Efficacy of INCB05...
# 3     4  NCT04103905  A Study of MIL62 in Treatment of CD20 Positive...
# 4     5  NCT02741388  A Phase Ib Study of Oral Selinexor in Adult Pa...
#
#    acronym     status         study results  \
# 0      NaN  Completed  No Results Available
# 1      NaN  Completed  No Results Available
# 2      NaN  Completed  No Results Available
# 3      NaN  Completed  No Results Available
# 4  SELINDA  Completed  No Results Available
#
#                                   conditions  \
# 0                           Lymphoma, B-Cell
# 1                                   Lymphoma
# 2                                   Lymphoma
# 3  CD20-positive B Cell Non-Hodgkin Lymphoma
# ...

# %%
df.columns
# Out:
# Index(['rank', 'nct number', 'title', 'acronym', 'status', 'study results',
#        'conditions', 'interventions', 'outcome measures',
#        'sponsor/collaborators', 'gender', 'age', 'phases', 'enrollment',
#        'funded bys', 'study type', 'study designs', 'other ids', 'start date',
#        'primary completion date', 'completion date', 'first posted',
#        'results first posted', 'last update posted', 'locations',
#        'study documents', 'url', 'duration'],
#       dtype='object')

# %%
df1= df[['duration','gender','age','enrollment','sponsor/collaborators']]

# %%
# Cut Level for duration
dcat=pd.cut(df1.duration, bins=[0,366,732,1100,3000], 
             labels=["a1year", "a2year" ,"a3year", "m3year"])
df1.insert(5, "Dcat", dcat)

# %%
df1.head()
# Out:
#    duration gender                                          age  enrollment  \
# 0    1209.0    All    18 Years and older   (Adult, Older Adult)         4.0
# 1    1979.0    All    18 Years and older   (Adult, Older Adult)        26.0
# 2    1504.0    All    18 Years and older   (Adult, Older Adult)        26.0
# 3    1204.0    All    18 Years and older   (Adult, Older Adult)        27.0
# 4    1824.0    All  18 Years to 70 Years   (Adult, Older Adult)        39.0
#
#                                sponsor/collaborators    Dcat
# 0         Eureka Therapeutics Inc.|Peking University  m3year
# 1  Alliance for Clinical Trials in Oncology|Natio...  m3year
# 2                                 Incyte Corporation  m3year
# 3                 Beijing Mabworks Biotech Co., Ltd.  m3year
# 4  The Lymphoma Academic Research Organisation|Ka...  m3year

# %% [markdown]
# ### EDA

# %%
fig=plt.figure()
ax=sns.violinplot(x="Dcat" , y="duration",palette="Set2", data=df1)
plt.show()

# %% [markdown]
# #### Duration of Phase 2
#
# It's about 5 years

# %%
sns.set(rc={'figure.figsize':(15,5)})
fig=plt.figure()
sns.histplot(data=df1, x="duration",kde=True, bins=30)
plt.axvline(df1["duration"].mean(),c="pink",ls="-", lw=3, label="Mean")
plt.axvline(df1["duration"].median(),c="darkseagreen",ls="-",lw=3,label="Median")
plt.title("Distribution of Duration", fontsize=20,fontweight="bold")
plt.legend()
plt.show()

# %% [markdown]
# ### Phase 2 enrollment
#
# It is about 50 people

# %%
sns.set(rc={'figure.figsize':(15,5)})
fig=plt.figure()
sns.histplot(data=df1, x="enrollment",kde=True, bins=30)
plt.axvline(df1["enrollment"].mean(),c="orchid",ls="-", lw=3, label="Mean")
plt.axvline(df1["enrollment"].median(),c="green",ls="-",lw=3,label="Median")
plt.title("Distribution of Enrollment", fontsize=20,fontweight="bold")
plt.legend()
plt.show()

# %%
def fplot(var,label):
    fig, ax=plt.subplots(1,3)
    sns.violinplot(x=var, y="duration",data=df1,palette="Set2",ax=ax[0])
    sns.histplot(df1,x="duration", hue=var, palette="Set2",kde=True,ax=ax[1])
    sns.countplot(x=var,hue="Dcat",data=df1,palette="Set2", ax=ax[2])
    plt.suptitle(label)
    return plt
fig.show()

# %%
fplot("gender","Gender")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
fplot("age","Age")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
df1['age'].value_counts().nlargest(20).plot(kind = 'barh',figsize = (10,5))
plt.title("Popular Enrollment Ages ")
plt.show()

# %%
df1['age'].value_counts().nlargest(10).plot(kind = 'barh',figsize = (10,5), 
                        color=("#c6ebd1","#8bdab2","#4fc5ad", "#38aaac","#359caa","#3482a4",
                            "#37659e","#40498e","#413d7b","#37284f","#241628"))
plt.title(" 10 Popular Age ")
plt.show()

# %%
df1['sponsor/collaborators'].value_counts().nlargest(10).plot(kind = 'barh',figsize = (10,5), 
                        color=("#c6ebd1","#8bdab2","#4fc5ad", "#38aaac","#359caa","#3482a4",
                            "#37659e","#40498e","#413d7b","#37284f","#241628"))
plt.title(" 10 Popular Sponsor ")
plt.show()

# %%
df1['sponsor/collaborators'].value_counts().nlargest(50).plot(kind = 'barh',figsize = (16,16))
plt.title("Popular Enrollment Ages ")
plt.show()

# %%
def histg(data, color , label):
    fig, ax = plt.subplots(1, 1, figsize=(12, 6))
    data.plot.hist(bins=5, color=color)
    plt.title(label)
    plt.show()

# %%
obs_by_sp = df1.groupby(['sponsor/collaborators'])['duration'].count()
histg(obs_by_sp,"#c6ebd1", "Sponsor")

# %%
sns.regplot(data=df1, x="enrollment", y="duration")
fig.show()

# %%
df1[["duration", "enrollment"]] = df1[["duration", "enrollment"]].fillna(0)
# Out:
# <ipython-input-91-0b3e4dfed07e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[["duration", "enrollment"]] = df1[["duration", "enrollment"]].fillna(0)

# %%
Y=df1["duration"]
X =df1["enrollment"]

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
reg=linear_model.LinearRegression()
reg.fit(df1[["enrollment"]],df1.duration)
# Out:
# LinearRegression()

# %%
model = reg().fit(X,Y)
model.score(X,Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-254094656c52> in <cell line: 1>()
# ----> 1 model = reg().fit(X,Y)
#       2 model.score(X,Y)
#
# TypeError: 'LinearRegression' object is not callable

# %%
Y_pred = reg.predict(X)
lin = pd.DataFrame({'Actual': Y, 'Predicted': Y_pred.flatten()})
display(lin)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-501c802cd9e7> in <cell line: 1>()
# ----> 1 Y_pred = reg.predict(X)
#       2 lin = pd.DataFrame({'Actual': Y, 'Predicted': Y_pred.flatten()})
#       3 display(lin)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# ...
